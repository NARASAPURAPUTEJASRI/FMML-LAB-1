# %% [markdown]
# <a href="https://colab.research.google.com/github/NARASAPURAPUTEJASRI/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 06:24:50--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   133MB/s    in 0.5s
#
# 2024-04-02 06:24:53 (133 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11325  1509.06957v2  Efficient index structures for fast approximat...  stat
# 10347   1209.6004v1  We develop a model of issue-specific voting be...  stat
# 36779   1411.0659v2  #SMT, or model counting for logical theories, ...    cs
# 6548   1703.02528v1  While the costs of human violence have attract...  stat
# 21870   1402.4884v2  "Deep Learning" methods attempt to learn gener...  stat
# ...             ...                                                ...   ...
# 23102  cs/0308034v1  In the paper will be presented a safety and se...    cs
# 32265   1402.4437v2  We present a new probabilistic model of compac...    cs
# 14686   1002.1095v1  This document discusses an approach and its ru...    cs
# 4258   1802.02669v2  We present PPFNet - Point Pair Feature NETwork...    cs
# 22178  1506.07959v1  Factorial hidden Markov models (FHMMs) are pow...  stat
#
#                                                    title  year  \
# 11325                                   Fast k-NN search  2015
# 10347               The Issue-Adjusted Ideal Point Model  2012
# 36779  Approximate Counting in SMT and Value Estimati...  2014
# 6548   Stopping GAN Violence: Generative Unadversaria...  2017
# 21870  Le Cam meets LeCun: Deficiency and Generic Fea...  2014
# ...                                                  ...   ...
# 23102       Fingerprint based bio-starter and bio-access  2003
# 32265  Learning the Irreducible Representations of Co...  2014
# 14686  Towards a Heuristic Categorization of Preposit...  2010
# 4258   PPFNet: Global Context Aware Local Features fo...  2018
# 22178  Factorized Asymptotic Bayesian Inference for F...  2015
#
#                                                 keywords
# 11325  [efficient, structures, approximate, applicati...
# 10347  [lawmakers, providing, exploratory, correlated...
# 36779  [generalizes, satisfying, assignments, computi...
# 6548   [attracted, attention, community, popularised,...
# 21870  [unsupervised, unlabelled, definition, charact...
# ...                                                  ...
# 23102  [presented, fingerprint, technology, fingerpri...
# 32265  [probabilistic, commutative, invariant, equiva...
# 14686  [discusses, rudimentary, realization, automati...
# 4258   [descriptor, correspondences, unorganized, des...
# 22178  [factorial, sequential, challenging, simultane...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11325    [efficient, structures, approximate, applicati...
# 10347    [lawmakers, providing, exploratory, correlated...
# 36779    [generalizes, satisfying, assignments, computi...
# 6548     [attracted, attention, community, popularised,...
# 21870    [unsupervised, unlabelled, definition, charact...
#                                ...
# 6448     [classification, identifies, hyperplane, maxim...
# 35028    [inference, regulatory, experimental, challeng...
# 22207    [descriptions, descriptions, information, repr...
# 32182    [reinforcement, addressing, continuous, optimi...
# 17180    [linguistic, demonstrative, adjective, frequen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8807 words.
# Out of those 4618 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1a0e3faa-86e3-482e-88d7-ae858f73f00d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a0e3faa-86e3-482e-88d7-ae858f73f00d")) {                    Plotly.newPlot(                        "1a0e3faa-86e3-482e-88d7-ae858f73f00d",                        [{"x":["construction","applications","multiplications","dimensional","parallelization","demonstrate","redundancy","recommendation","furthermore","approximate","straightforward","partitioning","efficient","structures","footprint","projections","projection","technique","additional","generated","computations","approaches","experiments","conventional","candidate","excessive","extensive","expensive","independently","implement","evaluations","available","providing","legislative","performance","inference","interpreting","political","exploratory","improvement","variational","prediction","algorithms","inherently","posterior","correlated","estimation","generalizes","solutions","underlying","implemented","probabilistic","sophisticated","heuristics","approximation","computing","polynomial","reduction","nondeterminism","satisfiability","assignments","information","arithmetic","exploiting","satisfying","application","simultaneously","grammatical","generator","attracted","proposing","community","carefully","distribution","generative","framework","dermatological","theoretically","likelihood","financial","anonymous","published","adversarial","attention","addressed","differences","unlabelled","characterize","unsupervised","definition","autoencoder","deficiency","illustrate","benchmarks","introduces","computational","selection","alleviating","capabilities","quantization","specifically","randomized","drawbacks","descriptors","achieving","efficiency","evaluation","descriptor","selecting","attribute","histograms","different","reformulate","quantitative","resolution","trainable","qualitative","improvements","equivalent","segmentation","fluctuate","thoroughly","variation","statistics","forecasting","seasonality","competition","combining","variables","presented","demonstrated","approximations","difficulties","asymptotic","particularly","computation","integrals","automated","dimensionality","statistical","investigated","determination","languages","suggested","manuscript","logarithmic","dependence","structure","properties","constructed","literature","frequencies","considered","portraits","performed","including","geometrical","correlation","combinations","consistency","classical","developed","benchmark","deviation","attractiveness","perception","automatic","complement","numerical","independent","particular","theoretical","condition","leveraging","complexity","convergence","techniques","algorithmic","transfers","regression","typically","knowledge","feedforward","representation","optimization","observations","procedure","alternative","development","predictions","chemistry","consistent","recognition","requisite","systematically","accurately","demonstrates","chemception","investigate","established"],"y":[62,440,4,176,3,553,19,20,164,112,25,17,393,126,18,19,45,216,111,171,30,447,633,99,31,2,161,59,43,57,54,314,92,1,878,240,15,18,5,159,70,239,577,17,34,31,191,25,141,137,82,185,28,44,107,150,62,89,2,16,13,678,5,84,13,239,114,16,30,25,29,93,35,203,118,542,0,39,72,13,4,35,100,158,33,40,5,39,142,39,22,3,64,91,58,301,165,3,47,24,181,22,18,50,83,176,278,33,49,44,13,747,3,70,114,24,52,131,54,194,1,11,64,59,16,0,37,101,132,188,98,36,33,17,63,154,1,108,54,158,50,11,123,26,13,15,17,323,198,42,142,17,126,1,133,232,14,66,31,48,114,196,218,11,6,51,170,20,91,116,261,161,53,46,248,101,368,41,7,112,102,345,13,401,331,87,119,92,113,63,4,97,384,2,23,59,46,0,129,57],"type":"bar"},{"x":["construction","applications","multiplica ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4618,), (4618, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Latent</span> <span style=''>Clothing</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103448);'>Attribute</span> <span style=''>Approach</span> <span style=''>for</span> <span style=''>Human</span> <span style=''>Pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>As</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>concerns</span> <span style=''>several</span> <span style=''>vision</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>image</span> <span style=''>parsing</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.6340425531914893);'>recognition</span> <span style=''>and</span> <span style=''>clothing</span> <span style='background-color:rgba(0, 255, 0, 0.6129032258064516);'>retrieval</span> <span style=''>human</span> <span style=''>pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>(HPE)</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensively</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>investigated</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>To</span> <span style=''>achieve</span> <span style=''>accurate</span> <span style=''>and</span> <span style=''>reliable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>human</span> <span style=''>pose</span> <span style=''>it</span> <span style=''>is</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.7037037037037037);'>recognized</span> <span style=''>that</span> <span style=''>the</span> <span style=''>clothing</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>attributes</span> <span style=''>are</span> <span style=''>useful</span> <span style=''>and</span> <span style=''>should</span> <span style=''>be</span> <span style=''>utilized</span> <span style=''>properly</span> <span style=''>Most</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>however</span> <span style=''>require</span> <span style=''>to</span> <span style=''>manually</span> <span style=''>annotate</span> <span style=''>the</span> <span style=''>clothing</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>attributes</span> <span style=''>and</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>very</span> <span style=''>costly</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>shall</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>explore</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>emphlatent</span> <span style=''>clothing</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103448);'>attribute</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>HPE</span> <span style=''>Unlike</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>models</span> <span style=''>the</span> <span style=''>clothing</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>attributes</span> <span style=''>as</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3465346534653465);'>variables</span> <span style=''>and</span> <span style=''>thus</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style=''>Non</span> <span style=''>Negative</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>A</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalence</span> <span style=''>between</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>(NMF)</span> <span style=''>and</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>As</span> <span style=''>NMF</span> <span style=''>and</span> <span style=''>many</span> <span style=''>of</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style=''>linear</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>NMF</span> <span style=''>with</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>general</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplicative</span> <span style=''>update</span> <span style=''>rules</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>problem</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style=''>NMF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>named</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>KNSC</span> <span style=''>Ncut</span> <span style=''>and</span> <span style=''>KNSC</span> <span style=''>Rcut</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>with</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>cut</span> <span style=''>and</span> <span style=''>ratio</span> <span style=''>cut</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>We</span> <span style=''>further</span> <span style=''>extend</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Sublinear</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Graphs</span> <br/><br/><span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>extends</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>for</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style=''>models</span> <span style=''>for</span> <span style=''>graphs</span> <span style=''>and</span> <span style=''>analyzes</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>The</span> <span style=''>results</span> <span style=''>are</span> <span style=''>(i)</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>(ii)</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>learning</span> <span style=''>rule</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>(iii)</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3841463414634146);'>convergence</span> <span style=''>theorem</span> <span style=''>for</span> <span style=''>the</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.44827586206896547);'>perceptron</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sublinearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style=''>case</span> <span style=''>and</span> <span style=''>(iv)</span> <span style=''>the</span> <span style=''>VC</span> <span style='background-color:rgba(255, 0, 0, 0.39698492462311546);'>dimension</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>results</span> <span style=''>on</span> <span style=''>graph</span> <span style=''>data</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sublinear</span> <span style=''>models</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>have</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>as</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>for</span> <span style=''>feature</span> <span style=''>vectors</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Restoring</span> <span style=''>the</span> <span style=''>Training</span> <span style=''>Set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style=''>in</span> <span style=''>an</span> <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifier</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>are</span> <span style=''>a</span> <span style=''>well</span> <span style=''>known</span> <span style=''>staple</span> <span style=''>of</span> <span style=''>modern</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>However</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>assess</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>such</span> <span style=''>models</span> <span style=''>Deep</span> <span style=''>models</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>on</span> <span style=''>a</span> <span style=''>given</span> <span style=''>training</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>set</span> <span style=''>but</span> <span style=''>can</span> <span style=''>easily</span> <span style=''>be</span> <span style=''>fooled</span> <span style=''>by</span> <span style=''>data</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>one</span> <span style=''>can</span> <span style=''>produce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>example</span> <span style=''>that</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>class</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activates</span> <span style=''>the</span> <span style=''>network</span> <span style=''>in</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>way</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>a</span> <span style=''>new</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructing</span> <span style=''>a</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>without</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09935668334524661)
# 	segmentation (0.06933523945675482)
# 	processing (0.10507505360972123)
# 	architecture (0.09185132237312366)
# 	information (0.24231593995711223)
# 	representation (0.14331665475339528)
# 	detection (0.12437455325232309)
# 	different (0.26697641172265907)
# 	convolutional (0.14295925661186562)
# 	recognition (0.13724088634739098)
#
# Some Statistics words are:
# 	algorithms (0.2902097902097902)
# 	variables (0.13586413586413587)
# 	algorithm (0.38161838161838163)
# 	statistical (0.15134865134865136)
# 	theoretical (0.15384615384615385)
# 	estimation (0.16633366633366634)
# 	distribution (0.18031968031968032)
# 	inference (0.1953046953046953)
# 	dimensional (0.1853146853146853)
# 	regression (0.1798201798201798)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="30e55fe9-ecfc-47a1-a49e-3a71e6c67e68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30e55fe9-ecfc-47a1-a49e-3a71e6c67e68")) {                    Plotly.newPlot(                        "30e55fe9-ecfc-47a1-a49e-3a71e6c67e68",                        [{"x":["construction","applications","multiplications","dimensional","parallelization","demonstrate","redundancy","recommendation","furthermore","approximate","straightforward","partitioning","efficient","structures","footprint","projections","projection","technique","additional","generated","computations","approaches","experiments","conventional","candidate","excessive","extensive","expensive","independently","implement","evaluations","available","providing","legislative","performance","inference","interpreting","political","exploratory","improvement","variational","prediction","algorithms","inherently","posterior","correlated","estimation","generalizes","solutions","underlying","implemented","probabilistic","sophisticated","heuristics","approximation","computing","polynomial","reduction","nondeterminism","satisfiability","assignments","information","arithmetic","exploiting","satisfying","application","simultaneously","grammatical","generator","attracted","proposing","community","carefully","distribution","generative","framework","dermatological","theoretically","likelihood","financial","anonymous","published","adversarial","attention","addressed","differences","unlabelled","characterize","unsupervised","definition","autoencoder","deficiency","illustrate","benchmarks","introduces","computational","selection","alleviating","capabilities","quantization","specifically","randomized","drawbacks","descriptors","achieving","efficiency","evaluation","descriptor","selecting","attribute","histograms","different","reformulate","quantitative","resolution","trainable","qualitative","improvements","equivalent","segmentation","fluctuate","thoroughly","variation","statistics","forecasting","seasonality","competition","combining","variables","presented","demonstrated","approximations","difficulties","asymptotic","particularly","computation","integrals","automated","dimensionality","statistical","investigated","determination","languages","suggested","manuscript","logarithmic","dependence","structure","properties","constructed","literature","frequencies","considered","portraits","performed","including","geometrical","correlation","combinations","consistency","classical","developed","benchmark","deviation","attractiveness","perception","automatic","complement","numerical","independent","particular","theoretical","condition","leveraging","complexity","convergence","techniques","algorithmic","transfers","regression","typically","knowledge","feedforward","representation","optimization","observations","procedure","alternative","development","predictions","chemistry","consistent","recognition","requisite","systematically","accurately","demonstrates","chemception","investigate","established","architectural","predicting","augmented","examining","resulting","introducing","outperforms","augmenting","localized","solvation","molecular","consuming","relevance","specified","bottleneck","diagnosing","informative","ultimately","interpretable","intuition","discovery","combination","mathematically","explanation","decisions","predictive","preliminary","unfortunately","correlations","limitation","adjustment","challenging","keyframes","accumulation","correction","incremental","introduce","unnecessary","effectiveness","experimental","algorithm","according","construct","comparisons","architecture","translating","distillation","filtering","translation","dimensions","describes","reproduced","discretized","subsampling ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	dermatological
# 	seasonality
# 	chemception
# 	solvation
# 	restaurants
# 	unanswered
# 	measurability
# 	countable
# 	uncountable
# 	manageable
# 	schizophrenia
# 	methylation
# 	semiparametric
# 	consortium
# 	influencing
# 	myocardial
# 	infarction
# 	electrocardiogram
# 	unverifiable
# 	negativity
# Some words which never appear in Statistics papers:
# 	nondeterminism
# 	satisfiability
# 	attractiveness
# 	keyframes
# 	covariant
# 	rotationally
# 	recognizers
# 	recognizable
# 	occlusions
# 	homologous
# 	september
# 	destruction
# 	retrained
# 	morphosyntactic
# 	justifications
# 	semantically
# 	translators
# 	translator
# 	supplementary
# 	declarative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0676728633658504e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
